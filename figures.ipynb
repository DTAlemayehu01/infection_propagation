# %% [markdown]
# # Figure Construction Ideas and Experiments
#
# - [ ] On an ER model is time a funciton of something or does it converge to a simple time.
#     - [ ] does graph sparsity impact the time taken to dst
# - [ ] First Step Prediction. Given the shortest time simulated at 1st frontier simulation step, can you guess the path?
# - [ ] Massive Node Simulation

# %%
from collections import defaultdict
from scipy import stats
from scipy.stats import erlang, expon, norm 
from itertools import product, combinations
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json
import time # benchmarking

# User Defined Modules
import Graph

from tree_source_localization import EdgeDistribution

# %% [markdown]
# # Test

# %%
pre_def = {
    "0,1": {
        "distribution": "N",
        "parameters": {
            "mu": 1.0,
            "sigma2": 1.0
        }
    },
    "1,2": {
        "distribution": "N",
        "parameters": {
            "mu": 1.0,
            "sigma2": 1.0
        }
    },
    "2,3": {
        "distribution": "N",
        "parameters": {
            "mu": 1.0,
            "sigma2": 1.0
        }
    },
    "3,4": {
        "distribution": "N",
        "parameters": {
            "mu": 1.0,
            "sigma2": 1.0
        }
    },
    "4,5": {
        "distribution": "N",
        "parameters": {
            "mu": 1.0,
            "sigma2": 1.0
        }
    },
    "5,6": {
        "distribution": "N",
        "parameters": {
            "mu": 1.0,
            "sigma2": 1.0
        }
    },
    "6,7": {
        "distribution": "N",
        "parameters": {
            "mu": 1.0,
            "sigma2": 1.0
        }
    },
    "7,8": {
        "distribution": "N",
        "parameters": {
            "mu": 1.0,
            "sigma2": 1.0
        }
    },
    "8,9": {
        "distribution": "N",
        "parameters": {
            "mu": 1.0,
            "sigma2": 1.0
        }
    },
    "9,10": {
        "distribution": "N",
        "parameters": {
            "mu": 1.0,
            "sigma2": 1.0
        }
    }
}

# %%
h = Graph.erdos_renyi(10, 0.34, force_connection=True, edge_dst=pre_def)
print(h.sparsity())
for v1, v2, rv in h.edge_set:
    print(f"{v1}->{v2}: {rv.dist_type}")
# Out:
# 0.4222222222222222
# 1->9: E
# 4->9: E
# 2->7: E
# 5->7: E
# 3->6: E
# 0->4: E
# 2->3: N
# 1->5: E
# 2->8: E
# 1->2: N
# 1->8: E
# 3->9: E
# 8->9: N
# 0->5: E
# 6->8: E
# 3->7: E
# 5->8: E
# 7->9: E
# 1->4: E

# %%
h.reset_data()
h.reset_simulation()
h.simulation_trial('0', '6', iters=100)
h.construct_path('0','6')
# Out:
# ['6', '0']

# %%
h.produce_histograms()

# %%
h.produce_extended_histograms()

# %%
data = Graph.erdos_renyi_simulation_trial(15, 0.7, '0', '3', iters=100, edge_dst=pre_def)

# %%
Graph.produce_histograms(data[0],data[1])

# %%
Graph.produce_extended_histograms(data[0],data[1])

# %% [markdown]
# # Test 2

# %%
n = 20
p = 1.2*np.log(n)/n
data = Graph.erdos_renyi_simulation_trial(n, p, '0', '3', iters=100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_15110/1613717092.py in ?()
#       1 n = 20
#       2 p = 1.2*np.log(n)/n
# ----> 3 data = Graph.erdos_renyi_simulation_trial(n, p, '0', '3', iters=100)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, src, dst, iters, **kwargs)
#     264 def erdos_renyi_simulation_trial(n, p, src, dst, iters=10**3, **kwargs):
#     265     path_counts = defaultdict(lambda: 0)
#     266     path_times = defaultdict(list)
#     267     for i in range(iters):
# --> 268         h = erdos_renyi(n, p, **kwargs)
#     269         time = h.simulate_gossip_rv(src, dst)
#     270         path = tuple(h.construct_path(src, dst)) # Randomly fails here?
#     271         path_counts[path] = path_counts[path] + 1
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ...
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
# --> 241         return erdos_renyi(n, p, force_connection=force_connection, **kwargs)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, force_connection, **kwargs)
#     236 def erdos_renyi(n, p, force_connection=True, **kwargs):
# --> 237     h = erdos_renyi_generator(n, p, **kwargs)
#     238     if force_connection and h.is_connected() and n == len(h.vertices()):
#     239         return h
#     240     else:
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(n, p, edge_dst, directed)
#     257                 edge_set[edge_paring] = { "distribution": "E", "parameters": { "lambda" : 1.0 }}
#     258     if not edge_set:
#     259         return erdos_renyi_generator(n,p, edge_dst=edge_dst, directed=directed)
#     260     else:
# --> 261         return Graph(edge_set, directed=directed)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(self, edge_json, node_size, directed)
#      25         self.edge_set = self.make_edge_set(edge_json)
#      26         # Graph creation
#      27         self._directed = directed
#      28         self.add_connections(self.edge_set)
# ---> 29         self._adjency_matrix = self.construct_matrix(self.edge_set)
#      30         # Distribution information
#      31         self._path_counts = defaultdict(lambda: 0)
#      32         self._path_times = defaultdict(list)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/Graph.py in ?(self, edge_set)
#      52     def construct_matrix(self, edge_set):
#      53         df = pd.DataFrame(edge_set)
#      54         df = df.pivot(index=0, columns=1, values=2)
#      55         if self._directed == False:
# ---> 56             df = df.combine_first(df.T)
#      57         if self._directed == True:
#      58             idx = df.columns.union(df.index)
#      59             df = df.reindex(index = idx, columns=idx, fill_value=np.inf)
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/.venv/lib/python3.14/site-packages/pandas/core/frame.py in ?(self, other)
#   10401                 self.columns.append(other.columns.difference(self.columns)), axis=1
#   10402             )
#   10403             combined = combined.astype(other.dtypes)
#   10404         else:
# > 10405             combined = self.combine(other, combiner, overwrite=False)
#   10406
#   10407         dtypes = {
#   10408             # Check for isinstance(..., (np.dtype, ExtensionDtype))
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/.venv/lib/python3.14/site-packages/pandas/core/frame.py in ?(self, other, func, fill_value, overwrite)
#   10325             else:
#   10326                 # if we have different dtypes, possibly promote
#   10327                 new_dtype = find_common_type([this_dtype, other_dtype])
#   10328                 series = series.astype(new_dtype)
# > 10329                 other_series = other_series.astype(new_dtype)
#   10330
#   10331             arr = func(series, other_series)
#   10332             if isinstance(new_dtype, np.dtype):
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/.venv/lib/python3.14/site-packages/pandas/core/generic.py in ?(self, dtype, copy, errors)
#    6539         else:
#    6540             # else, only a single dtype is given
#    6541             new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
# -> 6543             return res.__finalize__(self, method="astype")
#    6544
#    6545         # GH 33113: handle empty frame or series
#    6546         if not results:
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/.venv/lib/python3.14/site-packages/pandas/core/generic.py in ?(self, other, method, **kwargs)
#    6164                 # One could make the deepcopy unconditionally, but a deepcopy
#    6165                 # of an empty dict is 50x more expensive than the empty check.
#    6166                 self.attrs = deepcopy(other.attrs)
#    6167             self.flags.allows_duplicate_labels = (
# -> 6168                 self.flags.allows_duplicate_labels
#    6169                 and other.flags.allows_duplicate_labels
#    6170             )
#    6171             # For subclasses using _metadata.
#
# ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/.venv/lib/python3.14/site-packages/pandas/core/generic.py in ?(self)
# --> 360     @final
#     361     @property
#     362     def flags(self) -> Flags:
#     363         """
#
# KeyboardInterrupt:
