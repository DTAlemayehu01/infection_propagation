# %%
from collections import defaultdict
from scipy import stats
from scipy.stats import erlang, expon, norm 
from itertools import product, combinations
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json
import time # benchmarking

# User Defined Modules
import Graph

# %%
h = Graph.erdos_renyi(10, 0.6, force_connection=True)
h.edge_set
# Out:
# {('0', '1', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('0', '2', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('0', '3', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('0', '4', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('0', '5', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('0', '6', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('0', '7', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('0', '8', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('0', '9', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('1', '2', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('1', '4', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('1', '5', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('1', '6', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('2', '3', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('2', '6', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('2', '7', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('2', '9', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('3', '6', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('4', '5', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('4', '6', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('4', '7', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('4', '8', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('5', '7', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('5', '8', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('5', '9', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('6', '9', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('7', '8', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('7', '9', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>),
#  ('8', '9', <scipy.stats._continuous_distns.expon_gen at 0x7f7434a7e7b0>)}

# %%
h._adjency_matrix
# Out:
#            0          1          2          3          4          5  \
# 0        inf  <scipy...  <scipy...  <scipy...  <scipy...  <scipy...
# 1  <scipy...        inf  <scipy...        inf  <scipy...  <scipy...
# 2  <scipy...  <scipy...        inf  <scipy...        inf        inf
# 3  <scipy...        inf  <scipy...        inf        inf        inf
# 4  <scipy...  <scipy...        inf        inf        inf  <scipy...
# 5  <scipy...  <scipy...        inf        inf  <scipy...        inf
# 6  <scipy...  <scipy...  <scipy...  <scipy...  <scipy...        inf
# 7  <scipy...        inf  <scipy...        inf  <scipy...  <scipy...
# 8  <scipy...        inf        inf        inf  <scipy...  <scipy...
# 9  <scipy...        inf  <scipy...        inf        inf  <scipy...
#
#            6          7          8          9
# 0  <scipy...  <scipy...  <scipy...  <scipy...
# 1  <scipy...        inf        inf        inf
# 2  <scipy...  <scipy...        inf  <scipy...
# 3  <scipy...        inf        inf        inf
# 4  <scipy...  <scipy...  <scipy...        inf
# 5        inf  <scipy...  <scipy...  <scipy...
# 6        inf        inf        inf  <scipy...
# 7        inf        inf  <scipy...  <scipy...
# 8        inf  <scipy...        inf  <scipy...
# 9  <scipy...  <scipy...  <scipy...        inf

# %%
h.simulation_trial('1', '6')

# %%
h.produce_histograms()

# %%
h.produce_extended_histograms()
