# %%
from collections import defaultdict
from scipy import stats
from scipy.stats import erlang, expon, norm 
from itertools import product, combinations
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json
import time # benchmarking

# Repo Defined Modules
from infection_propagation import Graph
from infection_propagation import Figures

# %%
threshold_value = lambda x : np.log(x)/x

# %%
n = 10
p = 0.6
h = Graph.erdos_renyi(n, p, force_connection=True)
print(f"Threshold value: {threshold_value(n)}")
print(f"P value: {p}")
# Out:
# Threshold value: 0.23025850929940458
# P value: 0.6

# %%
h.sparsity()
# Out:
# 0.6222222222222222

# %%
len(h.edge_set)
# Out:
# 28

# %%
h.simulation_trial('0', '6', iters=10)

# %%
Figures.time_distribution(h._path_times)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 Figures.time_distribution(h._path_times)
#
# File ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/src/infection_propagation/Figures.py:10, in time_distribution(path_times)
#       8     full_data = full_data + times
#       9 _,_,bars = plt.hist(full_data, bins="rice") #,
# ---> 10 plt.set_title("Infection time distribution, all paths")
#      11 plt.bar_label(bars)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_title'

# %%
Figures.path_distribution(h._path_counts)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 Figures.path_distribution(h._path_counts)
#
# File ~/cuboulder/IMPORTANT_SIDE_STUFF_LIKE_JOB/research/infection_propagation/src/infection_propagation/Figures.py:17, in path_distribution(path_counts)
#      15 bar = plt.barh(path_names, list(path_counts.values()))
#      16 plt.bar_label(bar)
# ---> 17 plt.title("Path distribution")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_title'

# %%
Figures.time_per_path(h._path_times)
