# %%
# from collections import defaultdict
# from scipy import stats
# from scipy.stats import erlang, expon, norm 
# from itertools import product, combinations
# import numpy as np
# import matplotlib.pyplot as plt
# import pandas as pd
# import json
# import time # benchmarking

# Repo Defined Modules
from infection_propagation import Graph
from infection_propagation import Figures
# Out:
# Running cells with '.venv (Python 3.14.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/danny/cuboulder/in-progress/research-lladser/infection_propagation/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
threshold_value = lambda x : np.log(x)/x

# %%
n = 10
p = 0.6
h = Graph.erdos_renyi(n, p, force_connection=True)
print(f"Threshold value: {threshold_value(n)}")
print(f"P value: {p}")
# Out:
# Threshold value: 0.23025850929940458
# P value: 0.6

# %%
h.edge_density()
# Out:
# 0.7333333333333333

# %%
h.avg_degree()
# Out:
# np.float64(6.6)

# %%
h.simulation_trial('0', '6', iters=10)

# %%
Figures.time_distribution(h._path_times)

# %%
Figures.path_distribution(h._path_counts, h=0.01)

# %%
Figures.time_per_path(h._path_times)
