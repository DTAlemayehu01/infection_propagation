# %%
from infection_propagation import Graph
from infection_propagation import Figures
import importlib
import json
importlib.reload(Graph)
importlib.reload(Figures)
# Out:
# <module 'infection_propagation.Figures' from '/home/danny/cuboulder/in-progress/research-lladser/infection_propagation/src/infection_propagation/Figures.py'>

# %%
edge_dst = None
with open('../test_graphs/Pinto-tree.json') as json_file:
    edge_dst = json.load(json_file)
    
G = Graph.Graph(edge_dst)

# %%
p = set(G.vertices())
v = p.copy()
h = p.pop()
p.add(h)
print(len(p))
print(v == p)
v - p
# Out:
# 244
# True
# set()

# %%
a,b,c=G.is_connected()

# %%
b
# Out:
# {'1',
#  '10',
#  '100',
#  '101',
#  '102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '11',
#  '110',
#  '111',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '119',
#  '12',
#  '120',
#  '121',
#  '122',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '128',
#  '129',
#  '13',
#  '130',
#  '131',
#  '132',
#  '133',
#  '134',
#  '135',
#  '136',
#  '137',
#  '138',
#  '139',
#  '14',
#  '140',
#  '141',
#  '142',
#  '143',
#  '144',
#  '145',
#  '146',
#  '147',
#  '148',
#  '149',
#  '15',
#  '150',
#  '151',
#  '152',
#  '153',
#  '154',
#  '155',
#  '156',
#  '157',
#  '158',
#  '159',
#  '16',
#  '160',
#  '161',
#  '162',
#  '163',
#  '164',
#  '165',
#  '166',
#  '167',
#  '168',
#  '169',
#  '17',
#  '170',
#  '171',
#  '172',
#  '173',
#  '174',
#  '175',
#  '176',
#  '177',
#  '178',
#  '179',
#  '18',
#  '180',
#  '181',
#  '182',
#  '183',
#  '184',
#  '185',
#  '186',
#  '187',
#  '188',
#  '189',
#  '19',
# ...

# %%
G._graph['102']
# Out:
# {('197',
#   <tree_source_localization.EdgeDistribution.EdgeDistribution at 0x7f1a67e24980>)}

# %%
G._graph['197']
# Out:
# {('102',
#   <tree_source_localization.EdgeDistribution.EdgeDistribution at 0x7f1a67e24980>),
#  ('196',
#   <tree_source_localization.EdgeDistribution.EdgeDistribution at 0x7f1a67e2f230>),
#  ('198',
#   <tree_source_localization.EdgeDistribution.EdgeDistribution at 0x7f1a67e2f150>)}

# %%
G._graph['198']
# Out:
# {('197',
#   <tree_source_localization.EdgeDistribution.EdgeDistribution at 0x7f1a67e2f150>),
#  ('199',
#   <tree_source_localization.EdgeDistribution.EdgeDistribution at 0x7f1a67e2f070>),
#  ('200',
#   <tree_source_localization.EdgeDistribution.EdgeDistribution at 0x7f1a67e2ef90>)}

# %%
a
# Out:
# True

# %%
G._graph
# Out:
# defaultdict(set,
#             {'83': {('244',
#                <tree_source_localization.EdgeDistribution.EdgeDistribution at 0x7f1a67ff9e10>)},
#              '244': {('215',
#                <tree_source_localization.EdgeDistribution.EdgeDistribution at 0x7f1a67e2fe70>),
#               ('82',
#                <tree_source_localization.EdgeDistribution.EdgeDistribution at 0x7f1a67ff9ef0>),
#               ('83',
#                <tree_source_localization.EdgeDistribution.EdgeDistribution at 0x7f1a67ff9e10>)},
#              '71': {('193',
#                <tree_source_localization.EdgeDistribution.EdgeDistribution at 0x7f1a67ffa430>)},
#              '193': {('192',
#                <tree_source_localization.EdgeDistribution.EdgeDistribution at 0x7f1a67e34b40>),
#               ('194',
#                <tree_source_localization.EdgeDistribution.EdgeDistribution at 0x7f1a67e34a60>),
#               ('71',
# ...

# %%
c
# Out:
# {'1',
#  '10',
#  '100',
#  '101',
#  '102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '11',
#  '110',
#  '111',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '119',
#  '12',
#  '120',
#  '121',
#  '122',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '128',
#  '129',
#  '13',
#  '130',
#  '131',
#  '132',
#  '133',
#  '134',
#  '135',
#  '136',
#  '137',
#  '138',
#  '139',
#  '14',
#  '140',
#  '141',
#  '142',
#  '143',
#  '144',
#  '145',
#  '146',
#  '147',
#  '148',
#  '149',
#  '15',
#  '150',
#  '151',
#  '152',
#  '153',
#  '154',
#  '155',
#  '156',
#  '157',
#  '158',
#  '159',
#  '16',
#  '160',
#  '161',
#  '162',
#  '163',
#  '164',
#  '165',
#  '166',
#  '167',
#  '168',
#  '169',
#  '17',
#  '170',
#  '171',
#  '172',
#  '173',
#  '174',
#  '175',
#  '176',
#  '177',
#  '178',
#  '179',
#  '18',
#  '180',
#  '181',
#  '182',
#  '183',
#  '184',
#  '185',
#  '186',
#  '187',
#  '188',
#  '189',
#  '19',
# ...

# %%
len(G.edge_set)
# Out:
# 243

# %%
G._adjency_matrix
# Out:
#      121  122  123  124  125  126  127        128  129  130  ...   90   91  \
# 0                                                            ...
# 1    inf  inf  inf  inf  inf  inf  inf        inf  inf  inf  ...  inf  inf
# 10   inf  inf  inf  inf  inf  inf  inf  <tree_...  inf  inf  ...  inf  inf
# 100  inf  inf  inf  inf  inf  inf  inf        inf  inf  inf  ...  inf  inf
# 101  inf  inf  inf  inf  inf  inf  inf        inf  inf  inf  ...  inf  inf
# 102  inf  inf  inf  inf  inf  inf  inf        inf  inf  inf  ...  inf  inf
# ..   ...  ...  ...  ...  ...  ...  ...        ...  ...  ...  ...  ...  ...
# 95   inf  inf  inf  inf  inf  inf  inf        inf  inf  inf  ...  inf  inf
# 96   inf  inf  inf  inf  inf  inf  inf        inf  inf  inf  ...  inf  inf
# 97   inf  inf  inf  inf  inf  inf  inf        inf  inf  inf  ...  inf  inf
# 98   inf  inf  inf  inf  inf  inf  inf        inf  inf  inf  ...  inf  inf
# 99   inf  inf  inf  inf  inf  inf  inf        inf  inf  inf  ...  inf  inf
#
# ...

# %%
G.birectional_simulate_gossip_rv('1', '132')
# Out:
# 17.382598902875383

# %%
G.construct_path('1', '132')
# Out:
# ['132', '134', '135', '136', '1']

# %%
G.simulate_gossip_rv('1', '132')
# Out:
# 16.813992368267108

# %%
len(G.vertices())
# Out:
# 244
