# %%
from collections import defaultdict
from scipy import stats
from scipy.stats import erlang, expon, norm 
from itertools import product, combinations
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json
import time # benchmarking

# User Defined Modules
import Graph

# %%
threshold_value = lambda x : np.log(x)/x

# %%
n = 100
p = 0.6
h = Graph.erdos_renyi(n, p, force_connection=True)
print(f"Threshold value: {threshold_value(n)}")
print(f"P value: {p}")
# Out:
# Threshold value: 0.04605170185988092
# P value: 0.6

# %%
# Spasity measure
(h._adjency_matrix.to_numpy() == np.inf).mean()
# Out:
# np.float64(0.3862)

# %%
h.simulation_trial('0', '6')

# %%
h.produce_histograms()
